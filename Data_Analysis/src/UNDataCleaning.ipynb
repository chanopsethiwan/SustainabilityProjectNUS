# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Cleaning UNData (might convert to .py later as a function)

# %%
# write the function UNDataCleaning.py
def UNDataCleaning(country:str, csv_name:str, indicator_num: str): #all country name has capital for first letter
    df = pd.read_csv(f'../data/{country}/UNData/{csv_name}')
    df = df[['SeriesDescription', 'TimePeriod', 'Value']]
    df.dropna(inplace=True)
    df_pivot = df.pivot(index = ['TimePeriod'],
                    columns = 'SeriesDescription',
                    values = 'Value').reset_index()
    df_pivot.columns.name = None
    df_pivot.rename(columns = {'TimePeriod': 'Year'}, inplace = True)
    df_pivot.to_csv(f'../data/{country}/UNData/{indicator_num}Tidy.csv', index = False)

# %%
# example Usage 
UNDataCleaning(country= 'Thailand', csv_name='series-ER_CBD_SMTA-764.csv', indicator_num= '15.6.1')

# %% [markdown]
# ### Archived (used for testing)

# %%
df = pd.read_csv('../data/Thailand/UNData/series-AG_LND_FRSTCERT-764.csv')
df
# Out:
#     Goal  Target Indicator       SeriesCode  \
# 0   15.0    15.2    15.2.1  AG_LND_FRSTCERT
# 1   15.0    15.2    15.2.1  AG_LND_FRSTCERT
# 2   15.0    15.2    15.2.1  AG_LND_FRSTCERT
# 3   15.0    15.2    15.2.1  AG_LND_FRSTCERT
# 4   15.0    15.2    15.2.1  AG_LND_FRSTCERT
# 5   15.0    15.2    15.2.1  AG_LND_FRSTCERT
# 6   15.0    15.2    15.2.1  AG_LND_FRSTCERT
# 7   15.0    15.2    15.2.1  AG_LND_FRSTCERT
# 8   15.0    15.2    15.2.1  AG_LND_FRSTCERT
# 9   15.0    15.2    15.2.1  AG_LND_FRSTCERT
# 10  15.0    15.2    15.2.1  AG_LND_FRSTCERT
# 11  15.0    15.2    15.2.1  AG_LND_FRSTCERT
# 12   NaN     NaN       NaN              NaN
#
#                                     SeriesDescription  GeoAreaCode  \
# 0   Forest area certified under an independently v...        764.0
# 1   Forest area certified under an independently v...        764.0
# 2   Forest area certified under an independently v...        764.0
# 3   Forest area certified under an independently v...        764.0
# 4   Forest area certified under an independently v...        764.0
# 5   Forest area certified under an independently v...        764.0
# 6   Forest area certified under an independently v...        764.0
# 7   Forest area certified under an independently v...        764.0
# 8   Forest area certified under an independently v...        764.0
# 9   Forest area certified under an independently v...        764.0
# 10  Forest area certified under an independently v...        764.0
# 11  Forest area certified under an independently v...        764.0
# 12                                                NaN          NaN
#
#    GeoAreaName  TimePeriod   Value  Time_Detail  ...  UpperBound  LowerBound  \
# 0     Thailand      2000.0    0.00       2000.0  ...         NaN         NaN
# 1     Thailand      2005.0    2.94       2005.0  ...         NaN         NaN
# 2     Thailand      2010.0    7.64       2010.0  ...         NaN         NaN
# 3     Thailand      2015.0   44.24       2015.0  ...         NaN         NaN
# 4     Thailand      2016.0   61.80       2016.0  ...         NaN         NaN
# 5     Thailand      2017.0   63.37       2017.0  ...         NaN         NaN
# 6     Thailand      2018.0   56.88       2018.0  ...         NaN         NaN
# 7     Thailand      2019.0   75.78       2019.0  ...         NaN         NaN
# 8     Thailand      2020.0   88.67       2020.0  ...         NaN         NaN
# 9     Thailand      2021.0  118.05       2021.0  ...         NaN         NaN
# 10    Thailand      2022.0  125.64       2022.0  ...         NaN         NaN
# 11    Thailand      2023.0  150.22       2023.0  ...         NaN         NaN
# 12         NaN         NaN     NaN          NaN  ...         NaN         NaN
#
#     BasePeriod                                             Source GeoInfoUrl  \
# 0          NaN  No data on certified forest area in the FSC an...        NaN
# 1          NaN  Data submitted by FSC and PEFC secretariats (c...        NaN
# 2          NaN  Data submitted by FSC and PEFC secretariats (c...        NaN
# 3          NaN  Data submitted by FSC and PEFC secretariats (c...        NaN
# 4          NaN  Data submitted by FSC and PEFC secretariats (c...        NaN
# 5          NaN  Data submitted by FSC and PEFC secretariats (c...        NaN
# 6          NaN  Data submitted by FSC and PEFC secretariats (c...        NaN
# 7          NaN  Data submitted by FSC and PEFC secretariats (c...        NaN
# 8          NaN  Data submitted by FSC and PEFC secretariats (c...        NaN
# 9          NaN  Data submitted by FSC and PEFC secretariats (c...        NaN
# 10         NaN  Data submitted by FSC and PEFC secretariats (c...        NaN
# 11         NaN  FSC and PEFC (forest certification organizations)        NaN
# 12         NaN                                                NaN        NaN
#
#                     FootNote [Nature] [Observation Status] [Reporting Type]  \
# 0   No certified forest area        C                    A                G
# 1                        NaN        C                    A                G
# 2                        NaN        C                    A                G
# 3                        NaN        C                    A                G
# 4                        NaN        C                    A                G
# 5                        NaN        C                    A                G
# 6                        NaN        C                    A                G
# 7                        NaN        C                    A                G
# 8                        NaN        C                    A                G
# 9                        NaN        C                    A                G
# 10                       NaN        C                    A                G
# 11                       NaN        C                    A                G
# 12                       NaN      NaN                  NaN              NaN
#
#    [Units]
# 0    HA_TH
# 1    HA_TH
# 2    HA_TH
# 3    HA_TH
# 4    HA_TH
# 5    HA_TH
# 6    HA_TH
# 7    HA_TH
# 8    HA_TH
# 9    HA_TH
# 10   HA_TH
# 11   HA_TH
# 12     NaN
#
# [13 rows x 21 columns]

# %%
df = df[['SeriesDescription', 'TimePeriod', 'Value']]
df
# Out:
#                                     SeriesDescription  TimePeriod   Value
# 0   Forest area certified under an independently v...      2000.0    0.00
# 1   Forest area certified under an independently v...      2005.0    2.94
# 2   Forest area certified under an independently v...      2010.0    7.64
# 3   Forest area certified under an independently v...      2015.0   44.24
# 4   Forest area certified under an independently v...      2016.0   61.80
# 5   Forest area certified under an independently v...      2017.0   63.37
# 6   Forest area certified under an independently v...      2018.0   56.88
# 7   Forest area certified under an independently v...      2019.0   75.78
# 8   Forest area certified under an independently v...      2020.0   88.67
# 9   Forest area certified under an independently v...      2021.0  118.05
# 10  Forest area certified under an independently v...      2022.0  125.64
# 11  Forest area certified under an independently v...      2023.0  150.22
# 12                                                NaN         NaN     NaN

# %%
# drop the NaN value and rename TimePeriod to Year
df.dropna(inplace=True)
# Out:
# /var/folders/5n/m32d0hsx4959r42x3mssyjj40000gn/T/ipykernel_30594/334067596.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
# Use Pivot to change series description to a column
df_pivot = df.pivot(index = ['TimePeriod'],
                    columns = 'SeriesDescription',
                    values = 'Value').reset_index()
df_pivot.columns.name = None
df_pivot
# Out:
#     TimePeriod  \
# 0       2000.0
# 1       2005.0
# 2       2010.0
# 3       2015.0
# 4       2016.0
# 5       2017.0
# 6       2018.0
# 7       2019.0
# 8       2020.0
# 9       2021.0
# 10      2022.0
# 11      2023.0
#
#     Forest area certified under an independently verified certification scheme (thousands of hectares)
# 0                                                0.00
# 1                                                2.94
# 2                                                7.64
# 3                                               44.24
# 4                                               61.80
# 5                                               63.37
# 6                                               56.88
# 7                                               75.78
# 8                                               88.67
# 9                                              118.05
# 10                                             125.64
# 11                                             150.22

# %%
df_pivot.rename(columns = {'TimePeriod': 'Year'}, inplace = True)
df_pivot
# Out:
#       Year  \
# 0   2000.0
# 1   2005.0
# 2   2010.0
# 3   2015.0
# 4   2016.0
# 5   2017.0
# 6   2018.0
# 7   2019.0
# 8   2020.0
# 9   2021.0
# 10  2022.0
# 11  2023.0
#
#     Forest area certified under an independently verified certification scheme (thousands of hectares)
# 0                                                0.00
# 1                                                2.94
# 2                                                7.64
# 3                                               44.24
# 4                                               61.80
# 5                                               63.37
# 6                                               56.88
# 7                                               75.78
# 8                                               88.67
# 9                                              118.05
# 10                                             125.64
# 11                                             150.22

# %%
df_pivot.to_csv(f'../data/Thailand/UNData/15.2.1Tidy.csv', index = False)
